# %% [markdown]
# **THE SPARK FOUNDATION GRIP**
#
# **DATA SCIENCE AND BUSINESS ANALYTICS INTERN**
#
# **TASK 1:** PREDICTION USING SUPERVISED ML
#
# **AUTHOR:** MUTHU SUBRAMANIAN M

# %%
#IMPORTING THE LIBRARIES
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
URL = "http://bit.ly/w-data"

student_data = pd.read_csv(URL)
student_data
# Out:
#     Hours  Scores
# 0     2.5      21
# 1     5.1      47
# 2     3.2      27
# 3     8.5      75
# 4     3.5      30
# 5     1.5      20
# 6     9.2      88
# 7     5.5      60
# 8     8.3      81
# 9     2.7      25
# 10    7.7      85
# 11    5.9      62
# 12    4.5      41
# 13    3.3      42
# 14    1.1      17
# 15    8.9      95
# 16    2.5      30
# 17    1.9      24
# 18    6.1      67
# 19    7.4      69
# 20    2.7      30
# 21    4.8      54
# 22    3.8      35
# 23    6.9      76
# 24    7.8      86

# %% [markdown]
# **EXPLORATORY DATA ANALYSIS**

# %%
student_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Hours   25 non-null     float64
#  1   Scores  25 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 528.0 bytes

# %%
student_data.describe()
# Out:
#            Hours     Scores
# count  25.000000  25.000000
# mean    5.012000  51.480000
# std     2.525094  25.286887
# min     1.100000  17.000000
# 25%     2.700000  30.000000
# 50%     4.800000  47.000000
# 75%     7.400000  75.000000
# max     9.200000  95.000000

# %%
#SHAPE SHOWS THAT NO.OF ROWS AND COLUMNS IN DATA
student_data.shape
# Out:
# (25, 2)

# %%
#PLOTTING FOR STUDENT PERCENTAGE BY STUDY HOURS

student_data.plot(x='Hours', y='Scores', style= '*',color= 'black') 
plt.title('Students percentage and study hours');
plt.legend(loc ='upper left')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# **DATA CLEANING**

# %%
student_data.isnull().sum()
# Out:
# Hours     0
# Scores    0
# dtype: int64

# %%
student_data.mean()
# Out:
# Hours      5.012
# Scores    51.480
# dtype: float64

# %% [markdown]
# **SPLITING DATASET**

# %%
#IMPORTING REQUIRED ML LIBRARIES

import scipy.stats as stats
import sklearn as sk
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
#SPLIT STUDENT DATA INTO X AND Y

X = student_data.iloc[:, :-1].values  
Y = student_data.iloc[:, 1].values 
X,Y
# Out:
# (array([[2.5],
#         [5.1],
#         [3.2],
#         [8.5],
#         [3.5],
#         [1.5],
#         [9.2],
#         [5.5],
#         [8.3],
#         [2.7],
#         [7.7],
#         [5.9],
#         [4.5],
#         [3.3],
#         [1.1],
#         [8.9],
#         [2.5],
#         [1.9],
#         [6.1],
#         [7.4],
#         [2.7],
#         [4.8],
#         [3.8],
#         [6.9],
#         [7.8]]),
#  array([21, 47, 27, 75, 30, 20, 88, 60, 81, 25, 85, 62, 41, 42, 17, 95, 30,
#         24, 67, 69, 30, 54, 35, 76, 86]))

# %%
#SPLIT INTO TRAIN TEST SET

X_train, X_test, Y_train,Y_test = train_test_split(X,Y,test_size = 0.28)
print(X_train.shape)
print(X_test.shape)
# Out:
# (17, 1)
# (8, 1)

# %%
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (17,)
# (8,)

# %%
LR = LinearRegression()
LR.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
X_test
# Out:
# array([[1.1],
#        [1.5],
#        [3.5],
#        [3.8],
#        [7.7],
#        [7.4],
#        [2.5],
#        [3.3]])

# %%
Y_predict = LR.predict(X_test)
Y_predict
# Out:
# array([48.77306666, 74.94597003, 25.62011368, 59.84621809, 38.70656537,
#        25.62011368, 61.85951835, 32.66666459])

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(Y_test,Y_predict)
# Out:
# 22.51466110692067

# %%
# PREDICT THE 9.25 HOURS PER DAY

Y = LR.predict([[9.25]])
Y
# Out:
# array([93.56899743])

# %%
#IMPORT METRICS
from sklearn import metrics

# %%
#MEAN ABSOLUTE ERROR VALUE
metrics.mean_absolute_error(Y_test, Y_predict)
# Out:
# 4.605049611088949

# %% [markdown]
# **FINAL RESULT**

# %% [markdown]
# PREDICT SCORE OF 9.25 HOURS PER DAY IS **93.56899743**

# %% [markdown]
# **THANK YOU**
